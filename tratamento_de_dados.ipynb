# %% [markdown]
# <a href="https://colab.research.google.com/github/IagodFarias/Machine-Learning/blob/main/tratamento_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('top_rated_movies(tmdb).csv')
df.head()
# Out:
#         id                     title  \
# 0      278  The Shawshank Redemption
# 1      238             The Godfather
# 2      240     The Godfather Part II
# 3      424          Schindler's List
# 4  1356039             Counterattack
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23       5.522
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14       5.317
# 2  In the continuing saga of the Corleone crime f...   1974-12-20       4.747
# 3  The true story of how businessman Oskar Schind...   1993-12-15       4.457
# 4  When a hostage rescue mission creates a new en...   2025-02-27       9.430
#
#    vote_average  vote_count
# 0         8.708       27883
# 1         8.689       21151
# 2         8.570       12771
# 3         8.567       16219
# 4         8.524         431

# %%
print(df.dtypes)
df['release_date'] = pd.to_datetime(df['release_date'])
df.isna().sum()
# Out:
# id                       int64
# title                   object
# overview                object
# release_date    datetime64[ns]
# popularity             float64
# vote_average           float64
# vote_count               int64
# dtype: object
# id              0
# title           0
# overview        0
# release_date    2
# popularity      0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
df.describe()
# Out:
#                  id                   release_date   popularity  vote_average  \
# count  8.560000e+03                           8558  8560.000000   8560.000000
# mean   2.082396e+05  2004-04-15 22:54:02.439822336     3.721817      6.845229
# min    2.000000e+00            1902-06-15 00:00:00     0.003000      5.800000
# 25%    1.001850e+04            1996-07-17 06:00:00     3.533000      6.371000
# 50%    3.686550e+04            2009-09-11 12:00:00     3.557000      6.800000
# 75%    3.861218e+05            2017-07-17 00:00:00     3.817000      7.300000
# max    1.356039e+06            2025-02-28 00:00:00    29.661000      8.708000
# std    2.768840e+05                            NaN     0.770182      0.597392
#
#          vote_count
# count   8560.000000
# mean    2159.248715
# min      300.000000
# 25%      480.000000
# 50%      903.000000
# 75%     2193.250000
# max    37174.000000
# std     3370.513826

# %%
print(df[df.isna().any(axis = 1)])
# Out:
#            id   title                                           overview  \
# 5208  1198870  Return  A girl is at school. Suddenly it's as if she c...
# 5435   733668  Return  Eyüp decides to cross mount Ararat looking for...
#
#      release_date  popularity  vote_average  vote_count
# 5208          NaT       3.531         6.616         391
# 5435          NaT       3.531         6.564         380
